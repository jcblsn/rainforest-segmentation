# %% [markdown]
# # Google DeepLabV3+

# %%
import _02c_read_datasets
import _02_evaluate_model

import os
import numpy as np
import itertools
import matplotlib.pyplot as plt
import tensorflow as tf
from datetime import datetime
from tensorflow.keras.layers import Conv2D, MaxPooling2D, concatenate, UpSampling2D, BatchNormalization, Activation
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, jaccard_score
import pandas as pd
from tensorflow import keras
from tensorflow.keras import *

# %%
#load data
epochs = 20
batches = 16
input_width = 256
shuffled = True
augment = True #{True, False}
if augment:
    augmentation_settings = {
    "flip_left_right": 0,
    "flip_up_down": 0,
    "gaussian_blur": 0.2,
    "random_noise": 0.0,
    "random_brightness": 0.5,
    "random_contrast": 0.5}
else:
    augmentation_settings = None

train_dataset, val_dataset, test_dataset = _02c_read_datasets.load_datasets(augmented = augment)

# %% [markdown]
# ## ResNet50 backbone

# %% [markdown]
# ResNet traditionally is a powerful, deep CNN that has been shown to work well for image segmentation in the past. DeepLabV3 thus typically uses ResNet as a backbone. In this case, ResNet50 will be applied as is done in https://keras.io/examples/vision/deeplabv3_plus/#inference-on-validation-images, which will mainly serve as a benchmark. It is important to note that ResNet only allows for three input bands, which is why, for ResNet50, the the last band is eliminated to return to a rgb/3-band format using `eliminate_last_channel`. After that, `convolution_block` and `DilatedSpatialPyramidPooling` are specific building blocks for the DeepLabV3+ model `DeeplabV3Plus_ResNet50` using ResNet50 as a backbone.

# %%
# ResNet50 only allows for three input channels
def eliminate_last_channel(x, y):
    x = x[:, :, :, :3]
    return x, y

# Apply the transformation function to each element in the dataset
train_dataset_1 = train_dataset.map(eliminate_last_channel)
val_dataset_1 = val_dataset.map(eliminate_last_channel)
test_dataset_1 = test_dataset.map(eliminate_last_channel)

# Test the output
#for x, y in val_dataset_1:
#    print(x.shape, y.shape)

# %%
def convolution_block(
    block_input,
    num_filters=256,
    kernel_size=3,
    dilation_rate=1,
    padding="same",
    use_bias=False,
):
    x = layers.Conv2D(
        num_filters,
        kernel_size=kernel_size,
        dilation_rate=dilation_rate,
        padding="same",
        use_bias=use_bias,
        kernel_initializer=keras.initializers.HeNormal(),
    )(block_input)
    x = layers.BatchNormalization()(x)
    return tf.nn.relu(x)


def DilatedSpatialPyramidPooling(dspp_input):
    dims = dspp_input.shape
    x = layers.AveragePooling2D(pool_size=(dims[-3], dims[-2]))(dspp_input)
    x = convolution_block(x, kernel_size=1, use_bias=True)
    out_pool = layers.UpSampling2D(
        size=(dims[-3] // x.shape[1], dims[-2] // x.shape[2]), interpolation="bilinear",
    )(x)

    out_1 = convolution_block(dspp_input, kernel_size=1, dilation_rate=1)
    out_6 = convolution_block(dspp_input, kernel_size=3, dilation_rate=6)
    out_12 = convolution_block(dspp_input, kernel_size=3, dilation_rate=12)
    out_18 = convolution_block(dspp_input, kernel_size=3, dilation_rate=18)

    x = layers.Concatenate(axis=-1)([out_pool, out_1, out_6, out_12, out_18])
    output = convolution_block(x, kernel_size=1)
    return output

# %%
def DeeplabV3Plus_ResNet50(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, image_size, 3))
    resnet50 = keras.applications.ResNet50(
       weights="imagenet", include_top=False, input_tensor=model_input,
    )
    
    #Encoder
    x = resnet50.get_layer("conv4_block6_2_relu").output
    #print(x.shape)
    x = DilatedSpatialPyramidPooling(x)
    
    #Decoder
    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = resnet50.get_layer("conv2_block3_2_relu").output 
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)

    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    return keras.Model(inputs=model_input, outputs=model_output)


model = DeeplabV3Plus_ResNet50(image_size=256, num_classes=1)
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_4[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 128, 128, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 128, 128, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 64, 64, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 64, 64, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 64, 64, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 64, 64, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 64, 64, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 64, 64, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 64, 64, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 32, 32, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 32, 32, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 32, 32, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 32, 32, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 16, 16, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 16, 16, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 16, 16, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  average_pooling2d_3 (AveragePo  (None, 1, 1, 256)   0           ['conv4_block6_2_relu[0][0]']
#  oling2D)
#
#  conv2d_42 (Conv2D)             (None, 1, 1, 256)    65792       ['average_pooling2d_3[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_42[0][0]']
#  ormalization)
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 256)  65536       ['conv4_block6_2_relu[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 256)  589824      ['conv4_block6_2_relu[0][0]']
#
#  tf.nn.relu_27 (TFOpLambda)     (None, 1, 1, 256)    0           ['batch_normalization_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_46[0][0]']
#  ormalization)
#
#  up_sampling2d_9 (UpSampling2D)  (None, 16, 16, 256)  0          ['tf.nn.relu_27[0][0]']
#
#  tf.nn.relu_28 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_32[0][0]']
#
#  tf.nn.relu_29 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_33[0][0]']
#
#  tf.nn.relu_30 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_34[0][0]']
#
#  tf.nn.relu_31 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_35[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 16, 16, 1280  0           ['up_sampling2d_9[0][0]',
#                                 )                                 'tf.nn.relu_28[0][0]',
#                                                                   'tf.nn.relu_29[0][0]',
#                                                                   'tf.nn.relu_30[0][0]',
#                                                                   'tf.nn.relu_31[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 16, 16, 256)  327680      ['concatenate_6[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 64, 64, 48)   3072        ['conv2_block3_2_relu[0][0]']
#
#  tf.nn.relu_32 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 64, 64, 48)  192         ['conv2d_48[0][0]']
#  ormalization)
#
#  up_sampling2d_10 (UpSampling2D  (None, 64, 64, 256)  0          ['tf.nn.relu_32[0][0]']
#  )
#
#  tf.nn.relu_33 (TFOpLambda)     (None, 64, 64, 48)   0           ['batch_normalization_37[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 304)  0           ['up_sampling2d_10[0][0]',
#                                                                   'tf.nn.relu_33[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 64, 64, 256)  700416      ['concatenate_7[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_49[0][0]']
#  ormalization)
#
#  tf.nn.relu_34 (TFOpLambda)     (None, 64, 64, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 64, 64, 256)  589824      ['tf.nn.relu_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  tf.nn.relu_35 (TFOpLambda)     (None, 64, 64, 256)  0           ['batch_normalization_39[0][0]']
#
#  up_sampling2d_11 (UpSampling2D  (None, 256, 256, 25  0          ['tf.nn.relu_35[0][0]']
#  )                              6)
#
#  conv2d_51 (Conv2D)             (None, 256, 256, 1)  257         ['up_sampling2d_11[0][0]']
#
# ==================================================================================================
# Total params: 11,852,353
# Trainable params: 11,819,617
# Non-trainable params: 32,736
# __________________________________________________________________________________________________

# %%
# ----------- create directories
out_dir = '../results/' + datetime.now().strftime("%Y-%m-%d_%H-%M-%S") + '_DeepLabV3+_ResNet50/'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    os.makedirs(out_dir + '/plots')
    os.makedirs(out_dir + '/weights')
    os.makedirs(out_dir + '/predictions')
    os.makedirs(out_dir + '/bestweights')

    
# Define the path where you want to save the weights
checkpoint_path = out_dir + 'bestweights/' 

# Define the ModelCheckpoint callback
checkpoint = callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_best_only=True,
    monitor='val_accuracy', 
    mode='max', 
    verbose=1
)

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=["accuracy"]
)
history = model.fit(train_dataset_1, validation_data=val_dataset_1,epochs=epochs,callbacks=[checkpoint])

# %%
# ---------------------- save results


# Load the saved, optimal  weights
model.load_weights(checkpoint_path)

# Compile the model with the same optimizer and loss function used during training
model.compile(optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=["accuracy"])
model.save_weights(out_dir+'model.hdf5')

# ----------- plot the training and validation loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.savefig(out_dir + '/plots/' + 'loss.png')

# ----------- plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.legend()
plt.savefig(out_dir + '/plots/' + 'accuracy.png')

# ----------- save weights
model.save(out_dir + '/weights/' + 'model.h5')

# ----------- save predictions
def visualize_predictions(index, test_dataset, out_dir):
    test_data_iter = iter(itertools.cycle(test_dataset))

    for i in range(index + 1):
        image_batch, label_batch = next(test_data_iter)

    wrapped_index = index % batches
    image = image_batch[wrapped_index].numpy()
    image = image[:,:,:3]
    image_rgb = np.stack(
        (
            (image[:,:,0] - np.min(image[:,:,0])) * 255.0 / (np.max(image[:,:,0]) - np.min(image[:,:,0])),
            (image[:,:,1] - np.min(image[:,:,1])) * 255.0 / (np.max(image[:,:,1]) - np.min(image[:,:,1])),
            (image[:,:,2] - np.min(image[:,:,2])) * 255.0 / (np.max(image[:,:,2]) - np.min(image[:,:,2]))
        ),
        axis=-1
    ).astype(np.uint8)
    prediction = model.predict(np.expand_dims(image, axis=0))[0]
    ground_truth = label_batch[wrapped_index].numpy()

    fig, ax = plt.subplots(2, 2, figsize=(10, 10));
    ax[0,0].imshow(image_rgb);
    ax[0,0].set_title("Input Image");
    ax[0,1].imshow(np.squeeze(ground_truth), cmap='gray');
    ax[0,1].set_title("Ground Truth");
    ax[1,0].imshow(np.squeeze(prediction), cmap='gray')
    ax[1,0].set_title("Prediction")
    ax[1,1].imshow(np.squeeze(prediction) > 0.5, cmap='gray')
    ax[1,1].set_title("Prediction (binary)")

    for i in range(2):
        for j in range(2):
            ax[i,j].axis('off')
            
    
    plt.savefig(out_dir + '/predictions/' + 'comparison_' + str(index) + '.png');
for i in range(80):
    visualize_predictions(i, test_dataset, out_dir)

# ----------- save metrics

model_info = _02_evaluate_model.evaluate_model(
    "DeepLabV3+ with ResNet50 backbone", 
    test_dataset_1, 
    model, 
    (256, 256, 3), 
    shuffled, 
    batches, 
    epochs, 
    augmentation_settings=augmentation_settings, 
    threshold=0.5)
df = pd.DataFrame(model_info)
df.to_csv(os.path.join(out_dir, 'metrics.csv'), index=False)

# %% [markdown]
# ## Xception

# %% [markdown]
# The original Xception code is derived from:
#
# https://colab.research.google.com/github/mavenzer/Autism-Detection-Using_YOLO/blob/master/Tutorial_implementing_Xception_in_TensorFlow_2_0_using_the_Functional_API.ipynb#scrollTo=_cwgleGGqE9T
#
# Here, we adjust this code as is done in the paper. Corrections are indicated by `#Correction suggested by paper`.

# %%
def entry_flow(inputs):
    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(64, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    previous_block_activation = x  # Set aside residual
  
    # Blocks 2, 3, 4 are identical apart from the feature depth.
    list1=[128, 256, 728]
    for size in list1:
        idx=list1.index(size)+2
        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(size, 3, padding='same')(x)
        x = layers.BatchNormalization(name="block"+str(idx)+"_sepconv1_bn")(x)

        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(size, 3, padding='same')(x)
        x = layers.BatchNormalization(name="block"+str(idx)+"_sepconv2_bn")(x)

        #x = layers.MaxPooling2D(3, strides=2, padding='same')(x)
        #Correction suggested by paper
        x = layers.SeparableConv2D(size, 3, padding='same',strides=2)(x)
        x = layers.BatchNormalization(name="block"+str(idx)+"_sepconv3_bn")(x)
        x = layers.Activation('relu')(x)
    
        # Project residual
        residual = layers.Conv2D(
        size, 1, strides=2, padding='same')(previous_block_activation)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual
        
    return x


def middle_flow(x, num_blocks=16):
    previous_block_activation = x

    for i in range(num_blocks):
        prefix = "block" + str(i + 5)
        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(728, 3, padding='same')(x)
        x = layers.BatchNormalization(name=prefix + "_sepconv1_bn")(x)

        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(728, 3, padding='same')(x)
        x = layers.BatchNormalization(name=prefix + "_sepconv2_bn")(x)
    
        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(728, 3, padding='same')(x)
        x = layers.BatchNormalization(name=prefix + "_sepconv3_bn")(x)

        x = layers.add([x, previous_block_activation])  # Add back residual
        previous_block_activation = x  # Set aside next residual
    
    return x

def exit_flow(x, num_classes=1):

    previous_block_activation = x
    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(728, 3, padding='same')(x)
    x = layers.BatchNormalization(name="block" + str(21)+"_sepconv1_bn")(x)

    x = layers.Activation('relu')(x)
    x = layers.SeparableConv2D(1024, 3, padding='same')(x)
    x = layers.BatchNormalization(name="block" + str(21)+"_sepconv2_bn")(x)

    #x = layers.MaxPooling2D(3, strides=2, padding='same')(x)
    #Correction suggested by paper
    x = layers.SeparableConv2D(1024, 3, padding='same',strides=2)(x)
    x = layers.BatchNormalization(name="block" + str(21)+"_sepconv3_bn")(x)
    x = layers.Activation('relu')(x)

    # Project residual
    residual = layers.Conv2D(1024, 1, strides=2, padding='same')(previous_block_activation)
    x = layers.add([x, residual])  # Add back residual

    x = layers.SeparableConv2D(1536, 3, padding='same')(x)
    x = layers.BatchNormalization(name="block" + str(22)+"_sepconv1_bn")(x)
    x = layers.Activation('relu')(x)
    
    #Correction suggested by paper
    x = layers.SeparableConv2D(1536, 3, padding='same',strides=2)(x)
    x = layers.BatchNormalization(name="block" + str(22)+"_sepconv2_bn")(x)
    x = layers.Activation('relu')(x)

    x = layers.SeparableConv2D(2048, 3, padding='same')(x)
    x = layers.BatchNormalization(name="block" + str(22)+"_sepconv3_bn")(x)
    x = layers.Activation('relu')(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 1:
        activation = 'sigmoid'
    else:
        activation = 'softmax'
    return layers.Dense(num_classes, activation=activation)(x)

# %%
def DeeplabV3Plus_Xception(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, image_size, 4))
    
    outputs_xception = exit_flow(middle_flow(entry_flow(model_input)))
    xception = keras.Model(model_input, outputs_xception)
    
    #Encoder
    x = xception.get_layer("block21_sepconv2_bn").output #output stride=16 (fast fully convolutional mode)
    # output stride specifies the requested ratio of input to output spatial resolution
    print(x.shape)
    x = DilatedSpatialPyramidPooling(x)
    
    #Decoder
    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = xception.get_layer("block3_sepconv2_bn").output #block3_sepconv2_bn
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)
    
    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    return keras.Model(inputs=model_input, outputs=model_output)


model = DeeplabV3Plus_Xception(image_size=256, num_classes=1)
model.summary()
# Out:
# (None, 16, 16, 728)
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 256, 256, 4  0           []
#                                 )]
#
#  conv2d_84 (Conv2D)             (None, 128, 128, 32  1184        ['input_7[0][0]']
#                                 )
#
#  batch_normalization_62 (BatchN  (None, 128, 128, 32  128        ['conv2d_84[0][0]']
#  ormalization)                  )
#
#  activation_260 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_62[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 128, 128, 64  18496       ['activation_260[0][0]']
#                                 )
#
#  batch_normalization_63 (BatchN  (None, 128, 128, 64  256        ['conv2d_85[0][0]']
#  ormalization)                  )
#
#  activation_261 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_63[0][0]']
#                                 )
#
#  activation_262 (Activation)    (None, 128, 128, 64  0           ['activation_261[0][0]']
#                                 )
#
#  separable_conv2d_252 (Separabl  (None, 128, 128, 12  8896       ['activation_262[0][0]']
#  eConv2D)                       8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 128, 128, 12  512        ['separable_conv2d_252[0][0]']
#  lization)                      8)
#
#  activation_263 (Activation)    (None, 128, 128, 12  0           ['block2_sepconv1_bn[0][0]']
#                                 8)
#
#  separable_conv2d_253 (Separabl  (None, 128, 128, 12  17664      ['activation_263[0][0]']
#  eConv2D)                       8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 128, 128, 12  512        ['separable_conv2d_253[0][0]']
#  lization)                      8)
#
#  separable_conv2d_254 (Separabl  (None, 64, 64, 128)  17664      ['block2_sepconv2_bn[0][0]']
#  eConv2D)
#
#  block2_sepconv3_bn (BatchNorma  (None, 64, 64, 128)  512        ['separable_conv2d_254[0][0]']
#  lization)
#
#  activation_264 (Activation)    (None, 64, 64, 128)  0           ['block2_sepconv3_bn[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 64, 64, 128)  8320        ['activation_261[0][0]']
#
#  add_80 (Add)                   (None, 64, 64, 128)  0           ['activation_264[0][0]',
#                                                                   'conv2d_86[0][0]']
#
#  activation_265 (Activation)    (None, 64, 64, 128)  0           ['add_80[0][0]']
#
#  separable_conv2d_255 (Separabl  (None, 64, 64, 256)  34176      ['activation_265[0][0]']
#  eConv2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 64, 64, 256)  1024       ['separable_conv2d_255[0][0]']
#  lization)
#
#  activation_266 (Activation)    (None, 64, 64, 256)  0           ['block3_sepconv1_bn[0][0]']
#
#  separable_conv2d_256 (Separabl  (None, 64, 64, 256)  68096      ['activation_266[0][0]']
#  eConv2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 64, 64, 256)  1024       ['separable_conv2d_256[0][0]']
#  lization)
#
#  separable_conv2d_257 (Separabl  (None, 32, 32, 256)  68096      ['block3_sepconv2_bn[0][0]']
#  eConv2D)
#
#  block3_sepconv3_bn (BatchNorma  (None, 32, 32, 256)  1024       ['separable_conv2d_257[0][0]']
#  lization)
#
#  activation_267 (Activation)    (None, 32, 32, 256)  0           ['block3_sepconv3_bn[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 32, 32, 256)  33024       ['add_80[0][0]']
#
#  add_81 (Add)                   (None, 32, 32, 256)  0           ['activation_267[0][0]',
#                                                                   'conv2d_87[0][0]']
#
#  activation_268 (Activation)    (None, 32, 32, 256)  0           ['add_81[0][0]']
#
#  separable_conv2d_258 (Separabl  (None, 32, 32, 728)  189400     ['activation_268[0][0]']
#  eConv2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['separable_conv2d_258[0][0]']
#  lization)
#
#  activation_269 (Activation)    (None, 32, 32, 728)  0           ['block4_sepconv1_bn[0][0]']
#
#  separable_conv2d_259 (Separabl  (None, 32, 32, 728)  537264     ['activation_269[0][0]']
#  eConv2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['separable_conv2d_259[0][0]']
#  lization)
#
#  separable_conv2d_260 (Separabl  (None, 16, 16, 728)  537264     ['block4_sepconv2_bn[0][0]']
#  eConv2D)
#
#  block4_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_260[0][0]']
#  lization)
#
#  activation_270 (Activation)    (None, 16, 16, 728)  0           ['block4_sepconv3_bn[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 16, 16, 728)  187096      ['add_81[0][0]']
#
#  add_82 (Add)                   (None, 16, 16, 728)  0           ['activation_270[0][0]',
#                                                                   'conv2d_88[0][0]']
#
#  activation_271 (Activation)    (None, 16, 16, 728)  0           ['add_82[0][0]']
#
#  separable_conv2d_261 (Separabl  (None, 16, 16, 728)  537264     ['activation_271[0][0]']
#  eConv2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_261[0][0]']
#  lization)
#
#  activation_272 (Activation)    (None, 16, 16, 728)  0           ['block5_sepconv1_bn[0][0]']
#
#  separable_conv2d_262 (Separabl  (None, 16, 16, 728)  537264     ['activation_272[0][0]']
#  eConv2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_262[0][0]']
#  lization)
#
#  activation_273 (Activation)    (None, 16, 16, 728)  0           ['block5_sepconv2_bn[0][0]']
#
#  separable_conv2d_263 (Separabl  (None, 16, 16, 728)  537264     ['activation_273[0][0]']
#  eConv2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_263[0][0]']
#  lization)
#
#  add_83 (Add)                   (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_82[0][0]']
#
#  activation_274 (Activation)    (None, 16, 16, 728)  0           ['add_83[0][0]']
#
#  separable_conv2d_264 (Separabl  (None, 16, 16, 728)  537264     ['activation_274[0][0]']
#  eConv2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_264[0][0]']
#  lization)
#
#  activation_275 (Activation)    (None, 16, 16, 728)  0           ['block6_sepconv1_bn[0][0]']
#
#  separable_conv2d_265 (Separabl  (None, 16, 16, 728)  537264     ['activation_275[0][0]']
#  eConv2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_265[0][0]']
#  lization)
#
#  activation_276 (Activation)    (None, 16, 16, 728)  0           ['block6_sepconv2_bn[0][0]']
#
#  separable_conv2d_266 (Separabl  (None, 16, 16, 728)  537264     ['activation_276[0][0]']
#  eConv2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_266[0][0]']
#  lization)
#
#  add_84 (Add)                   (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_83[0][0]']
#
#  activation_277 (Activation)    (None, 16, 16, 728)  0           ['add_84[0][0]']
#
#  separable_conv2d_267 (Separabl  (None, 16, 16, 728)  537264     ['activation_277[0][0]']
#  eConv2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_267[0][0]']
#  lization)
#
#  activation_278 (Activation)    (None, 16, 16, 728)  0           ['block7_sepconv1_bn[0][0]']
#
#  separable_conv2d_268 (Separabl  (None, 16, 16, 728)  537264     ['activation_278[0][0]']
#  eConv2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_268[0][0]']
#  lization)
#
#  activation_279 (Activation)    (None, 16, 16, 728)  0           ['block7_sepconv2_bn[0][0]']
#
#  separable_conv2d_269 (Separabl  (None, 16, 16, 728)  537264     ['activation_279[0][0]']
#  eConv2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_269[0][0]']
#  lization)
#
#  add_85 (Add)                   (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_84[0][0]']
#
#  activation_280 (Activation)    (None, 16, 16, 728)  0           ['add_85[0][0]']
#
#  separable_conv2d_270 (Separabl  (None, 16, 16, 728)  537264     ['activation_280[0][0]']
#  eConv2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_270[0][0]']
#  lization)
#
#  activation_281 (Activation)    (None, 16, 16, 728)  0           ['block8_sepconv1_bn[0][0]']
#
#  separable_conv2d_271 (Separabl  (None, 16, 16, 728)  537264     ['activation_281[0][0]']
#  eConv2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_271[0][0]']
#  lization)
#
#  activation_282 (Activation)    (None, 16, 16, 728)  0           ['block8_sepconv2_bn[0][0]']
#
#  separable_conv2d_272 (Separabl  (None, 16, 16, 728)  537264     ['activation_282[0][0]']
#  eConv2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_272[0][0]']
#  lization)
#
#  add_86 (Add)                   (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_85[0][0]']
#
#  activation_283 (Activation)    (None, 16, 16, 728)  0           ['add_86[0][0]']
#
#  separable_conv2d_273 (Separabl  (None, 16, 16, 728)  537264     ['activation_283[0][0]']
#  eConv2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_273[0][0]']
#  lization)
#
#  activation_284 (Activation)    (None, 16, 16, 728)  0           ['block9_sepconv1_bn[0][0]']
#
#  separable_conv2d_274 (Separabl  (None, 16, 16, 728)  537264     ['activation_284[0][0]']
#  eConv2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_274[0][0]']
#  lization)
#
#  activation_285 (Activation)    (None, 16, 16, 728)  0           ['block9_sepconv2_bn[0][0]']
#
#  separable_conv2d_275 (Separabl  (None, 16, 16, 728)  537264     ['activation_285[0][0]']
#  eConv2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_275[0][0]']
#  lization)
#
#  add_87 (Add)                   (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_86[0][0]']
#
#  activation_286 (Activation)    (None, 16, 16, 728)  0           ['add_87[0][0]']
#
#  separable_conv2d_276 (Separabl  (None, 16, 16, 728)  537264     ['activation_286[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_276[0][0]']
#  alization)
#
#  activation_287 (Activation)    (None, 16, 16, 728)  0           ['block10_sepconv1_bn[0][0]']
#
#  separable_conv2d_277 (Separabl  (None, 16, 16, 728)  537264     ['activation_287[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_277[0][0]']
#  alization)
#
#  activation_288 (Activation)    (None, 16, 16, 728)  0           ['block10_sepconv2_bn[0][0]']
#
#  separable_conv2d_278 (Separabl  (None, 16, 16, 728)  537264     ['activation_288[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_278[0][0]']
#  alization)
#
#  add_88 (Add)                   (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_87[0][0]']
#
#  activation_289 (Activation)    (None, 16, 16, 728)  0           ['add_88[0][0]']
#
#  separable_conv2d_279 (Separabl  (None, 16, 16, 728)  537264     ['activation_289[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_279[0][0]']
#  alization)
#
#  activation_290 (Activation)    (None, 16, 16, 728)  0           ['block11_sepconv1_bn[0][0]']
#
#  separable_conv2d_280 (Separabl  (None, 16, 16, 728)  537264     ['activation_290[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_280[0][0]']
#  alization)
#
#  activation_291 (Activation)    (None, 16, 16, 728)  0           ['block11_sepconv2_bn[0][0]']
#
#  separable_conv2d_281 (Separabl  (None, 16, 16, 728)  537264     ['activation_291[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_281[0][0]']
#  alization)
#
#  add_89 (Add)                   (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_88[0][0]']
#
#  activation_292 (Activation)    (None, 16, 16, 728)  0           ['add_89[0][0]']
#
#  separable_conv2d_282 (Separabl  (None, 16, 16, 728)  537264     ['activation_292[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_282[0][0]']
#  alization)
#
#  activation_293 (Activation)    (None, 16, 16, 728)  0           ['block12_sepconv1_bn[0][0]']
#
#  separable_conv2d_283 (Separabl  (None, 16, 16, 728)  537264     ['activation_293[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_283[0][0]']
#  alization)
#
#  activation_294 (Activation)    (None, 16, 16, 728)  0           ['block12_sepconv2_bn[0][0]']
#
#  separable_conv2d_284 (Separabl  (None, 16, 16, 728)  537264     ['activation_294[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_284[0][0]']
#  alization)
#
#  add_90 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_89[0][0]']
#
#  activation_295 (Activation)    (None, 16, 16, 728)  0           ['add_90[0][0]']
#
#  separable_conv2d_285 (Separabl  (None, 16, 16, 728)  537264     ['activation_295[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_285[0][0]']
#  alization)
#
#  activation_296 (Activation)    (None, 16, 16, 728)  0           ['block13_sepconv1_bn[0][0]']
#
#  separable_conv2d_286 (Separabl  (None, 16, 16, 728)  537264     ['activation_296[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_286[0][0]']
#  alization)
#
#  average_pooling2d_6 (AveragePo  (None, 1, 1, 728)   0           ['block13_sepconv2_bn[0][0]']
#  oling2D)
#
#  conv2d_90 (Conv2D)             (None, 1, 1, 256)    186624      ['average_pooling2d_6[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_90[0][0]']
#  ormalization)
#
#  conv2d_91 (Conv2D)             (None, 16, 16, 256)  186368      ['block13_sepconv2_bn[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 16, 16, 256)  1677312     ['block13_sepconv2_bn[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 16, 16, 256)  1677312     ['block13_sepconv2_bn[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 16, 16, 256)  1677312     ['block13_sepconv2_bn[0][0]']
#
#  tf.nn.relu_54 (TFOpLambda)     (None, 1, 1, 256)    0           ['batch_normalization_64[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_66 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_92[0][0]']
#  ormalization)
#
#  batch_normalization_67 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_93[0][0]']
#  ormalization)
#
#  batch_normalization_68 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_94[0][0]']
#  ormalization)
#
#  up_sampling2d_18 (UpSampling2D  (None, 16, 16, 256)  0          ['tf.nn.relu_54[0][0]']
#  )
#
#  tf.nn.relu_55 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_65[0][0]']
#
#  tf.nn.relu_56 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_66[0][0]']
#
#  tf.nn.relu_57 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_67[0][0]']
#
#  tf.nn.relu_58 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_68[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 16, 16, 1280  0           ['up_sampling2d_18[0][0]',
#                                 )                                 'tf.nn.relu_55[0][0]',
#                                                                   'tf.nn.relu_56[0][0]',
#                                                                   'tf.nn.relu_57[0][0]',
#                                                                   'tf.nn.relu_58[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 16, 16, 256)  327680      ['concatenate_12[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_95[0][0]']
#  ormalization)
#
#  conv2d_96 (Conv2D)             (None, 64, 64, 48)   12288       ['block3_sepconv2_bn[0][0]']
#
#  tf.nn.relu_59 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_69[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 64, 64, 48)  192         ['conv2d_96[0][0]']
#  ormalization)
#
#  up_sampling2d_19 (UpSampling2D  (None, 64, 64, 256)  0          ['tf.nn.relu_59[0][0]']
#  )
#
#  tf.nn.relu_60 (TFOpLambda)     (None, 64, 64, 48)   0           ['batch_normalization_70[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 304)  0           ['up_sampling2d_19[0][0]',
#                                                                   'tf.nn.relu_60[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 64, 64, 256)  700416      ['concatenate_13[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_97[0][0]']
#  ormalization)
#
#  tf.nn.relu_61 (TFOpLambda)     (None, 64, 64, 256)  0           ['batch_normalization_71[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 64, 64, 256)  589824      ['tf.nn.relu_61[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_98[0][0]']
#  ormalization)
#
#  tf.nn.relu_62 (TFOpLambda)     (None, 64, 64, 256)  0           ['batch_normalization_72[0][0]']
#
#  up_sampling2d_20 (UpSampling2D  (None, 256, 256, 25  0          ['tf.nn.relu_62[0][0]']
#  )                              6)
#
#  conv2d_99 (Conv2D)             (None, 256, 256, 1)  257         ['up_sampling2d_20[0][0]']
#
# ==================================================================================================
# Total params: 22,828,721
# Trainable params: 22,779,809
# Non-trainable params: 48,912
# __________________________________________________________________________________________________

# %%
# ----------- create directories
out_dir = '../results/' + datetime.now().strftime("%Y-%m-%d_%H-%M-%S") + '_DeepLabV3+_Xception/'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    os.makedirs(out_dir + '/plots')
    os.makedirs(out_dir + '/weights')
    os.makedirs(out_dir + '/predictions')
    os.makedirs(out_dir + '/bestweights')

    
# Define the path where you want to save the weights
checkpoint_path = out_dir + 'bestweights/' 

# Define the ModelCheckpoint callback
checkpoint = callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_best_only=True,
    monitor='val_accuracy', 
    mode='max', 
    verbose=1
)

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=["accuracy"]
)
history = model.fit(train_dataset, validation_data=val_dataset,epochs=epochs,callbacks=[checkpoint])

# %%
# ---------------------- save results

# Load the saved, optimal  weights
model.load_weights(checkpoint_path)
# Compile the model with the same optimizer and loss function used during training
model.compile(optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=["accuracy"])
model.save_weights(out_dir+'model.hdf5')


# ----------- plot the training and validation loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.savefig(out_dir + '/plots/' + 'loss.png')

# ----------- plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.legend()
plt.savefig(out_dir + '/plots/' + 'accuracy.png')

# ----------- save weights
model.save(out_dir + '/weights/' + 'model.h5')

# ----------- save predictions
def visualize_predictions(index, test_dataset, out_dir):
    test_data_iter = iter(itertools.cycle(test_dataset))

    for i in range(index + 1):
        image_batch, label_batch = next(test_data_iter)

    wrapped_index = index % batches
    image = image_batch[wrapped_index].numpy()

    image_rgb = np.stack(
        (
            (image[:,:,0] - np.min(image[:,:,0])) * 255.0 / (np.max(image[:,:,0]) - np.min(image[:,:,0])),
            (image[:,:,1] - np.min(image[:,:,1])) * 255.0 / (np.max(image[:,:,1]) - np.min(image[:,:,1])),
            (image[:,:,2] - np.min(image[:,:,2])) * 255.0 / (np.max(image[:,:,2]) - np.min(image[:,:,2]))
        ),
        axis=-1
    ).astype(np.uint8)

    prediction = model.predict(np.expand_dims(image, axis=0))[0]
    ground_truth = label_batch[wrapped_index].numpy()

    fig, ax = plt.subplots(2, 2, figsize=(10, 10))
    ax[0,0].imshow(image_rgb)
    ax[0,0].set_title("Input Image")
    ax[0,1].imshow(np.squeeze(ground_truth), cmap='gray')
    ax[0,1].set_title("Ground Truth")
    ax[1,0].imshow(np.squeeze(prediction), cmap='gray')
    ax[1,0].set_title("Prediction")
    ax[1,1].imshow(np.squeeze(prediction) > 0.5, cmap='gray')
    ax[1,1].set_title("Prediction (binary)")

    for i in range(2):
        for j in range(2):
            ax[i,j].axis('off')

    plt.savefig(out_dir + '/predictions/' + 'comparison_' + str(index) + '.png')
    #plt.show()
for i in range(80):
    visualize_predictions(i, test_dataset, out_dir)

# ----------- save metrics

model_info = _02_evaluate_model.evaluate_model(
    "DeepLabV3+ with Xception backbone",
    test_dataset, 
    model, 
    (256,256,4), 
    shuffled, 
    batches, 
    epochs, 
    augmentation_settings=augmentation_settings, 
    threshold=0.5)
df = pd.DataFrame(model_info)
df.to_csv(os.path.join(out_dir, 'metrics.csv'), index=False)

# %% [markdown]
# ## Xception with three bands

# %%
def DeeplabV3Plus_Xception_3(image_size, num_classes):
    model_input = keras.Input(shape=(image_size, image_size, 3))
    
    outputs = exit_flow(middle_flow(entry_flow(model_input)))
    xception = keras.Model(model_input, outputs)
    
    #Encoder
    x = xception.get_layer("block21_sepconv2_bn").output #output stride=16 (fast fully convolutional mode)
    x = DilatedSpatialPyramidPooling(x)
    
    #Decoder
    input_a = layers.UpSampling2D(
        size=(image_size // 4 // x.shape[1], image_size // 4 // x.shape[2]),
        interpolation="bilinear",
    )(x)
    input_b = xception.get_layer("block3_sepconv2_bn").output
    input_b = convolution_block(input_b, num_filters=48, kernel_size=1)
    x = layers.Concatenate(axis=-1)([input_a, input_b])
    x = convolution_block(x)
    x = convolution_block(x)
    x = layers.UpSampling2D(
        size=(image_size // x.shape[1], image_size // x.shape[2]),
        interpolation="bilinear",
    )(x)
    model_output = layers.Conv2D(num_classes, kernel_size=(1, 1), padding="same")(x)
    return keras.Model(inputs=model_input, outputs=model_output)


model = DeeplabV3Plus_Xception_3(image_size=256, num_classes=1)
model.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_68 (Conv2D)             (None, 128, 128, 32  896         ['input_6[0][0]']
#                                 )
#
#  batch_normalization_51 (BatchN  (None, 128, 128, 32  128        ['conv2d_68[0][0]']
#  ormalization)                  )
#
#  activation_195 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_51[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 128, 128, 64  18496       ['activation_195[0][0]']
#                                 )
#
#  batch_normalization_52 (BatchN  (None, 128, 128, 64  256        ['conv2d_69[0][0]']
#  ormalization)                  )
#
#  activation_196 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_52[0][0]']
#                                 )
#
#  activation_197 (Activation)    (None, 128, 128, 64  0           ['activation_196[0][0]']
#                                 )
#
#  separable_conv2d_189 (Separabl  (None, 128, 128, 12  8896       ['activation_197[0][0]']
#  eConv2D)                       8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 128, 128, 12  512        ['separable_conv2d_189[0][0]']
#  lization)                      8)
#
#  activation_198 (Activation)    (None, 128, 128, 12  0           ['block2_sepconv1_bn[0][0]']
#                                 8)
#
#  separable_conv2d_190 (Separabl  (None, 128, 128, 12  17664      ['activation_198[0][0]']
#  eConv2D)                       8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 128, 128, 12  512        ['separable_conv2d_190[0][0]']
#  lization)                      8)
#
#  separable_conv2d_191 (Separabl  (None, 64, 64, 128)  17664      ['block2_sepconv2_bn[0][0]']
#  eConv2D)
#
#  block2_sepconv3_bn (BatchNorma  (None, 64, 64, 128)  512        ['separable_conv2d_191[0][0]']
#  lization)
#
#  activation_199 (Activation)    (None, 64, 64, 128)  0           ['block2_sepconv3_bn[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 64, 64, 128)  8320        ['activation_196[0][0]']
#
#  add_60 (Add)                   (None, 64, 64, 128)  0           ['activation_199[0][0]',
#                                                                   'conv2d_70[0][0]']
#
#  activation_200 (Activation)    (None, 64, 64, 128)  0           ['add_60[0][0]']
#
#  separable_conv2d_192 (Separabl  (None, 64, 64, 256)  34176      ['activation_200[0][0]']
#  eConv2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 64, 64, 256)  1024       ['separable_conv2d_192[0][0]']
#  lization)
#
#  activation_201 (Activation)    (None, 64, 64, 256)  0           ['block3_sepconv1_bn[0][0]']
#
#  separable_conv2d_193 (Separabl  (None, 64, 64, 256)  68096      ['activation_201[0][0]']
#  eConv2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 64, 64, 256)  1024       ['separable_conv2d_193[0][0]']
#  lization)
#
#  separable_conv2d_194 (Separabl  (None, 32, 32, 256)  68096      ['block3_sepconv2_bn[0][0]']
#  eConv2D)
#
#  block3_sepconv3_bn (BatchNorma  (None, 32, 32, 256)  1024       ['separable_conv2d_194[0][0]']
#  lization)
#
#  activation_202 (Activation)    (None, 32, 32, 256)  0           ['block3_sepconv3_bn[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 32, 32, 256)  33024       ['add_60[0][0]']
#
#  add_61 (Add)                   (None, 32, 32, 256)  0           ['activation_202[0][0]',
#                                                                   'conv2d_71[0][0]']
#
#  activation_203 (Activation)    (None, 32, 32, 256)  0           ['add_61[0][0]']
#
#  separable_conv2d_195 (Separabl  (None, 32, 32, 728)  189400     ['activation_203[0][0]']
#  eConv2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 32, 32, 728)  2912       ['separable_conv2d_195[0][0]']
#  lization)
#
#  activation_204 (Activation)    (None, 32, 32, 728)  0           ['block4_sepconv1_bn[0][0]']
#
#  separable_conv2d_196 (Separabl  (None, 32, 32, 728)  537264     ['activation_204[0][0]']
#  eConv2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 32, 32, 728)  2912       ['separable_conv2d_196[0][0]']
#  lization)
#
#  separable_conv2d_197 (Separabl  (None, 16, 16, 728)  537264     ['block4_sepconv2_bn[0][0]']
#  eConv2D)
#
#  block4_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_197[0][0]']
#  lization)
#
#  activation_205 (Activation)    (None, 16, 16, 728)  0           ['block4_sepconv3_bn[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 16, 16, 728)  187096      ['add_61[0][0]']
#
#  add_62 (Add)                   (None, 16, 16, 728)  0           ['activation_205[0][0]',
#                                                                   'conv2d_72[0][0]']
#
#  activation_206 (Activation)    (None, 16, 16, 728)  0           ['add_62[0][0]']
#
#  separable_conv2d_198 (Separabl  (None, 16, 16, 728)  537264     ['activation_206[0][0]']
#  eConv2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_198[0][0]']
#  lization)
#
#  activation_207 (Activation)    (None, 16, 16, 728)  0           ['block5_sepconv1_bn[0][0]']
#
#  separable_conv2d_199 (Separabl  (None, 16, 16, 728)  537264     ['activation_207[0][0]']
#  eConv2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_199[0][0]']
#  lization)
#
#  activation_208 (Activation)    (None, 16, 16, 728)  0           ['block5_sepconv2_bn[0][0]']
#
#  separable_conv2d_200 (Separabl  (None, 16, 16, 728)  537264     ['activation_208[0][0]']
#  eConv2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_200[0][0]']
#  lization)
#
#  add_63 (Add)                   (None, 16, 16, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_62[0][0]']
#
#  activation_209 (Activation)    (None, 16, 16, 728)  0           ['add_63[0][0]']
#
#  separable_conv2d_201 (Separabl  (None, 16, 16, 728)  537264     ['activation_209[0][0]']
#  eConv2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_201[0][0]']
#  lization)
#
#  activation_210 (Activation)    (None, 16, 16, 728)  0           ['block6_sepconv1_bn[0][0]']
#
#  separable_conv2d_202 (Separabl  (None, 16, 16, 728)  537264     ['activation_210[0][0]']
#  eConv2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_202[0][0]']
#  lization)
#
#  activation_211 (Activation)    (None, 16, 16, 728)  0           ['block6_sepconv2_bn[0][0]']
#
#  separable_conv2d_203 (Separabl  (None, 16, 16, 728)  537264     ['activation_211[0][0]']
#  eConv2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_203[0][0]']
#  lization)
#
#  add_64 (Add)                   (None, 16, 16, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_63[0][0]']
#
#  activation_212 (Activation)    (None, 16, 16, 728)  0           ['add_64[0][0]']
#
#  separable_conv2d_204 (Separabl  (None, 16, 16, 728)  537264     ['activation_212[0][0]']
#  eConv2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_204[0][0]']
#  lization)
#
#  activation_213 (Activation)    (None, 16, 16, 728)  0           ['block7_sepconv1_bn[0][0]']
#
#  separable_conv2d_205 (Separabl  (None, 16, 16, 728)  537264     ['activation_213[0][0]']
#  eConv2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_205[0][0]']
#  lization)
#
#  activation_214 (Activation)    (None, 16, 16, 728)  0           ['block7_sepconv2_bn[0][0]']
#
#  separable_conv2d_206 (Separabl  (None, 16, 16, 728)  537264     ['activation_214[0][0]']
#  eConv2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_206[0][0]']
#  lization)
#
#  add_65 (Add)                   (None, 16, 16, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_64[0][0]']
#
#  activation_215 (Activation)    (None, 16, 16, 728)  0           ['add_65[0][0]']
#
#  separable_conv2d_207 (Separabl  (None, 16, 16, 728)  537264     ['activation_215[0][0]']
#  eConv2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_207[0][0]']
#  lization)
#
#  activation_216 (Activation)    (None, 16, 16, 728)  0           ['block8_sepconv1_bn[0][0]']
#
#  separable_conv2d_208 (Separabl  (None, 16, 16, 728)  537264     ['activation_216[0][0]']
#  eConv2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_208[0][0]']
#  lization)
#
#  activation_217 (Activation)    (None, 16, 16, 728)  0           ['block8_sepconv2_bn[0][0]']
#
#  separable_conv2d_209 (Separabl  (None, 16, 16, 728)  537264     ['activation_217[0][0]']
#  eConv2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_209[0][0]']
#  lization)
#
#  add_66 (Add)                   (None, 16, 16, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_65[0][0]']
#
#  activation_218 (Activation)    (None, 16, 16, 728)  0           ['add_66[0][0]']
#
#  separable_conv2d_210 (Separabl  (None, 16, 16, 728)  537264     ['activation_218[0][0]']
#  eConv2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_210[0][0]']
#  lization)
#
#  activation_219 (Activation)    (None, 16, 16, 728)  0           ['block9_sepconv1_bn[0][0]']
#
#  separable_conv2d_211 (Separabl  (None, 16, 16, 728)  537264     ['activation_219[0][0]']
#  eConv2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_211[0][0]']
#  lization)
#
#  activation_220 (Activation)    (None, 16, 16, 728)  0           ['block9_sepconv2_bn[0][0]']
#
#  separable_conv2d_212 (Separabl  (None, 16, 16, 728)  537264     ['activation_220[0][0]']
#  eConv2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 16, 16, 728)  2912       ['separable_conv2d_212[0][0]']
#  lization)
#
#  add_67 (Add)                   (None, 16, 16, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_66[0][0]']
#
#  activation_221 (Activation)    (None, 16, 16, 728)  0           ['add_67[0][0]']
#
#  separable_conv2d_213 (Separabl  (None, 16, 16, 728)  537264     ['activation_221[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_213[0][0]']
#  alization)
#
#  activation_222 (Activation)    (None, 16, 16, 728)  0           ['block10_sepconv1_bn[0][0]']
#
#  separable_conv2d_214 (Separabl  (None, 16, 16, 728)  537264     ['activation_222[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_214[0][0]']
#  alization)
#
#  activation_223 (Activation)    (None, 16, 16, 728)  0           ['block10_sepconv2_bn[0][0]']
#
#  separable_conv2d_215 (Separabl  (None, 16, 16, 728)  537264     ['activation_223[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_215[0][0]']
#  alization)
#
#  add_68 (Add)                   (None, 16, 16, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_67[0][0]']
#
#  activation_224 (Activation)    (None, 16, 16, 728)  0           ['add_68[0][0]']
#
#  separable_conv2d_216 (Separabl  (None, 16, 16, 728)  537264     ['activation_224[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_216[0][0]']
#  alization)
#
#  activation_225 (Activation)    (None, 16, 16, 728)  0           ['block11_sepconv1_bn[0][0]']
#
#  separable_conv2d_217 (Separabl  (None, 16, 16, 728)  537264     ['activation_225[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_217[0][0]']
#  alization)
#
#  activation_226 (Activation)    (None, 16, 16, 728)  0           ['block11_sepconv2_bn[0][0]']
#
#  separable_conv2d_218 (Separabl  (None, 16, 16, 728)  537264     ['activation_226[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_218[0][0]']
#  alization)
#
#  add_69 (Add)                   (None, 16, 16, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_68[0][0]']
#
#  activation_227 (Activation)    (None, 16, 16, 728)  0           ['add_69[0][0]']
#
#  separable_conv2d_219 (Separabl  (None, 16, 16, 728)  537264     ['activation_227[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_219[0][0]']
#  alization)
#
#  activation_228 (Activation)    (None, 16, 16, 728)  0           ['block12_sepconv1_bn[0][0]']
#
#  separable_conv2d_220 (Separabl  (None, 16, 16, 728)  537264     ['activation_228[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_220[0][0]']
#  alization)
#
#  activation_229 (Activation)    (None, 16, 16, 728)  0           ['block12_sepconv2_bn[0][0]']
#
#  separable_conv2d_221 (Separabl  (None, 16, 16, 728)  537264     ['activation_229[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_221[0][0]']
#  alization)
#
#  add_70 (Add)                   (None, 16, 16, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_69[0][0]']
#
#  activation_230 (Activation)    (None, 16, 16, 728)  0           ['add_70[0][0]']
#
#  separable_conv2d_222 (Separabl  (None, 16, 16, 728)  537264     ['activation_230[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_222[0][0]']
#  alization)
#
#  activation_231 (Activation)    (None, 16, 16, 728)  0           ['block13_sepconv1_bn[0][0]']
#
#  separable_conv2d_223 (Separabl  (None, 16, 16, 728)  537264     ['activation_231[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_223[0][0]']
#  alization)
#
#  activation_232 (Activation)    (None, 16, 16, 728)  0           ['block13_sepconv2_bn[0][0]']
#
#  separable_conv2d_224 (Separabl  (None, 16, 16, 728)  537264     ['activation_232[0][0]']
#  eConv2D)
#
#  block13_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_224[0][0]']
#  alization)
#
#  add_71 (Add)                   (None, 16, 16, 728)  0           ['block13_sepconv3_bn[0][0]',
#                                                                   'add_70[0][0]']
#
#  activation_233 (Activation)    (None, 16, 16, 728)  0           ['add_71[0][0]']
#
#  separable_conv2d_225 (Separabl  (None, 16, 16, 728)  537264     ['activation_233[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_225[0][0]']
#  alization)
#
#  activation_234 (Activation)    (None, 16, 16, 728)  0           ['block14_sepconv1_bn[0][0]']
#
#  separable_conv2d_226 (Separabl  (None, 16, 16, 728)  537264     ['activation_234[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_226[0][0]']
#  alization)
#
#  activation_235 (Activation)    (None, 16, 16, 728)  0           ['block14_sepconv2_bn[0][0]']
#
#  separable_conv2d_227 (Separabl  (None, 16, 16, 728)  537264     ['activation_235[0][0]']
#  eConv2D)
#
#  block14_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_227[0][0]']
#  alization)
#
#  add_72 (Add)                   (None, 16, 16, 728)  0           ['block14_sepconv3_bn[0][0]',
#                                                                   'add_71[0][0]']
#
#  activation_236 (Activation)    (None, 16, 16, 728)  0           ['add_72[0][0]']
#
#  separable_conv2d_228 (Separabl  (None, 16, 16, 728)  537264     ['activation_236[0][0]']
#  eConv2D)
#
#  block15_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_228[0][0]']
#  alization)
#
#  activation_237 (Activation)    (None, 16, 16, 728)  0           ['block15_sepconv1_bn[0][0]']
#
#  separable_conv2d_229 (Separabl  (None, 16, 16, 728)  537264     ['activation_237[0][0]']
#  eConv2D)
#
#  block15_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_229[0][0]']
#  alization)
#
#  activation_238 (Activation)    (None, 16, 16, 728)  0           ['block15_sepconv2_bn[0][0]']
#
#  separable_conv2d_230 (Separabl  (None, 16, 16, 728)  537264     ['activation_238[0][0]']
#  eConv2D)
#
#  block15_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_230[0][0]']
#  alization)
#
#  add_73 (Add)                   (None, 16, 16, 728)  0           ['block15_sepconv3_bn[0][0]',
#                                                                   'add_72[0][0]']
#
#  activation_239 (Activation)    (None, 16, 16, 728)  0           ['add_73[0][0]']
#
#  separable_conv2d_231 (Separabl  (None, 16, 16, 728)  537264     ['activation_239[0][0]']
#  eConv2D)
#  block16_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_231[0][0]']
#  alization)
#
#  activation_240 (Activation)    (None, 16, 16, 728)  0           ['block16_sepconv1_bn[0][0]']
#
#  separable_conv2d_232 (Separabl  (None, 16, 16, 728)  537264     ['activation_240[0][0]']
#  eConv2D)
#
#  block16_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_232[0][0]']
#  alization)
#
#  activation_241 (Activation)    (None, 16, 16, 728)  0           ['block16_sepconv2_bn[0][0]']
#
#  separable_conv2d_233 (Separabl  (None, 16, 16, 728)  537264     ['activation_241[0][0]']
#  eConv2D)
#
#  block16_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_233[0][0]']
#  alization)
#
#  add_74 (Add)                   (None, 16, 16, 728)  0           ['block16_sepconv3_bn[0][0]',
#                                                                   'add_73[0][0]']
#
#  activation_242 (Activation)    (None, 16, 16, 728)  0           ['add_74[0][0]']
#
#  separable_conv2d_234 (Separabl  (None, 16, 16, 728)  537264     ['activation_242[0][0]']
#  eConv2D)
#
#  block17_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_234[0][0]']
#  alization)
#
#  activation_243 (Activation)    (None, 16, 16, 728)  0           ['block17_sepconv1_bn[0][0]']
#
#  separable_conv2d_235 (Separabl  (None, 16, 16, 728)  537264     ['activation_243[0][0]']
#  eConv2D)
#
#  block17_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_235[0][0]']
#  alization)
#
#  activation_244 (Activation)    (None, 16, 16, 728)  0           ['block17_sepconv2_bn[0][0]']
#
#  separable_conv2d_236 (Separabl  (None, 16, 16, 728)  537264     ['activation_244[0][0]']
#  eConv2D)
#
#  block17_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_236[0][0]']
#  alization)
#
#  add_75 (Add)                   (None, 16, 16, 728)  0           ['block17_sepconv3_bn[0][0]',
#                                                                   'add_74[0][0]']
#
#  activation_245 (Activation)    (None, 16, 16, 728)  0           ['add_75[0][0]']
#
#  separable_conv2d_237 (Separabl  (None, 16, 16, 728)  537264     ['activation_245[0][0]']
#  eConv2D)
#
#  block18_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_237[0][0]']
#  alization)
#
#  activation_246 (Activation)    (None, 16, 16, 728)  0           ['block18_sepconv1_bn[0][0]']
#
#  separable_conv2d_238 (Separabl  (None, 16, 16, 728)  537264     ['activation_246[0][0]']
#  eConv2D)
#
#  block18_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_238[0][0]']
#  alization)
#
#  activation_247 (Activation)    (None, 16, 16, 728)  0           ['block18_sepconv2_bn[0][0]']
#
#  separable_conv2d_239 (Separabl  (None, 16, 16, 728)  537264     ['activation_247[0][0]']
#  eConv2D)
#
#  block18_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_239[0][0]']
#  alization)
#
#  add_76 (Add)                   (None, 16, 16, 728)  0           ['block18_sepconv3_bn[0][0]',
#                                                                   'add_75[0][0]']
#
#  activation_248 (Activation)    (None, 16, 16, 728)  0           ['add_76[0][0]']
#
#  separable_conv2d_240 (Separabl  (None, 16, 16, 728)  537264     ['activation_248[0][0]']
#  eConv2D)
#
#  block19_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_240[0][0]']
#  alization)
#
#  activation_249 (Activation)    (None, 16, 16, 728)  0           ['block19_sepconv1_bn[0][0]']
#
#  separable_conv2d_241 (Separabl  (None, 16, 16, 728)  537264     ['activation_249[0][0]']
#  eConv2D)
#
#  block19_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_241[0][0]']
#  alization)
#
#  activation_250 (Activation)    (None, 16, 16, 728)  0           ['block19_sepconv2_bn[0][0]']
#
#  separable_conv2d_242 (Separabl  (None, 16, 16, 728)  537264     ['activation_250[0][0]']
#  eConv2D)
#
#  block19_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_242[0][0]']
#  alization)
#
#  add_77 (Add)                   (None, 16, 16, 728)  0           ['block19_sepconv3_bn[0][0]',
#                                                                   'add_76[0][0]']
#
#  activation_251 (Activation)    (None, 16, 16, 728)  0           ['add_77[0][0]']
#
#  separable_conv2d_243 (Separabl  (None, 16, 16, 728)  537264     ['activation_251[0][0]']
#  eConv2D)
#
#  block20_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_243[0][0]']
#  alization)
#
#  activation_252 (Activation)    (None, 16, 16, 728)  0           ['block20_sepconv1_bn[0][0]']
#
#  separable_conv2d_244 (Separabl  (None, 16, 16, 728)  537264     ['activation_252[0][0]']
#  eConv2D)
#
#  block20_sepconv2_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_244[0][0]']
#  alization)
#
#  activation_253 (Activation)    (None, 16, 16, 728)  0           ['block20_sepconv2_bn[0][0]']
#
#  separable_conv2d_245 (Separabl  (None, 16, 16, 728)  537264     ['activation_253[0][0]']
#  eConv2D)
#
#  block20_sepconv3_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_245[0][0]']
#  alization)
#
#  add_78 (Add)                   (None, 16, 16, 728)  0           ['block20_sepconv3_bn[0][0]',
#                                                                   'add_77[0][0]']
#
#  activation_254 (Activation)    (None, 16, 16, 728)  0           ['add_78[0][0]']
#
#  separable_conv2d_246 (Separabl  (None, 16, 16, 728)  537264     ['activation_254[0][0]']
#  eConv2D)
#
#  block21_sepconv1_bn (BatchNorm  (None, 16, 16, 728)  2912       ['separable_conv2d_246[0][0]']
#  alization)
#
#  activation_255 (Activation)    (None, 16, 16, 728)  0           ['block21_sepconv1_bn[0][0]']
#
#  separable_conv2d_247 (Separabl  (None, 16, 16, 1024  753048     ['activation_255[0][0]']
#  eConv2D)                       )
#
#  block21_sepconv2_bn (BatchNorm  (None, 16, 16, 1024  4096       ['separable_conv2d_247[0][0]']
#  alization)                     )
#
#  average_pooling2d_5 (AveragePo  (None, 1, 1, 1024)  0           ['block21_sepconv2_bn[0][0]']
#  oling2D)
#
#  conv2d_74 (Conv2D)             (None, 1, 1, 256)    262400      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_74[0][0]']
#  ormalization)
#
#  conv2d_75 (Conv2D)             (None, 16, 16, 256)  262144      ['block21_sepconv2_bn[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 16, 16, 256)  2359296     ['block21_sepconv2_bn[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 16, 16, 256)  2359296     ['block21_sepconv2_bn[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 16, 16, 256)  2359296     ['block21_sepconv2_bn[0][0]']
#
#  tf.nn.relu_45 (TFOpLambda)     (None, 1, 1, 256)    0           ['batch_normalization_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_75[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_76[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_77[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_78[0][0]']
#  ormalization)
#
#  up_sampling2d_15 (UpSampling2D  (None, 16, 16, 256)  0          ['tf.nn.relu_45[0][0]']
#  )
#
#  tf.nn.relu_46 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_54[0][0]']
#
#  tf.nn.relu_47 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_55[0][0]']
#
#  tf.nn.relu_48 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_56[0][0]']
#
#  tf.nn.relu_49 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_57[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 16, 16, 1280  0           ['up_sampling2d_15[0][0]',
#                                 )                                 'tf.nn.relu_46[0][0]',
#                                                                   'tf.nn.relu_47[0][0]',
#                                                                   'tf.nn.relu_48[0][0]',
#                                                                   'tf.nn.relu_49[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 16, 16, 256)  327680      ['concatenate_10[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 16, 16, 256)  1024       ['conv2d_79[0][0]']
#  ormalization)
#
#  conv2d_80 (Conv2D)             (None, 64, 64, 48)   12288       ['block3_sepconv2_bn[0][0]']
#
#  tf.nn.relu_50 (TFOpLambda)     (None, 16, 16, 256)  0           ['batch_normalization_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 64, 64, 48)  192         ['conv2d_80[0][0]']
#  ormalization)
#
#  up_sampling2d_16 (UpSampling2D  (None, 64, 64, 256)  0          ['tf.nn.relu_50[0][0]']
#  )
#
#  tf.nn.relu_51 (TFOpLambda)     (None, 64, 64, 48)   0           ['batch_normalization_59[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 64, 64, 304)  0           ['up_sampling2d_16[0][0]',
#                                                                   'tf.nn.relu_51[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 64, 64, 256)  700416      ['concatenate_11[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_81[0][0]']
#  ormalization)
#
#  tf.nn.relu_52 (TFOpLambda)     (None, 64, 64, 256)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 64, 64, 256)  589824      ['tf.nn.relu_52[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_82[0][0]']
#  ormalization)
#
#  tf.nn.relu_53 (TFOpLambda)     (None, 64, 64, 256)  0           ['batch_normalization_61[0][0]']
#
#  up_sampling2d_17 (UpSampling2D  (None, 256, 256, 25  0          ['tf.nn.relu_53[0][0]']
#  )                              6)
#
#  conv2d_83 (Conv2D)             (None, 256, 256, 1)  257         ['up_sampling2d_17[0][0]']
#
# ==================================================================================================
# Total params: 38,207,129
# Trainable params: 38,122,681
# Non-trainable params: 84,448
# __________________________________________________________________________________________________

# %%
# ----------- create directories
out_dir = '../results/' + datetime.now().strftime("%Y-%m-%d_%H-%M-%S") + '_DeepLabV3+_Xception_3bands/'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
    os.makedirs(out_dir + '/plots')
    os.makedirs(out_dir + '/weights')
    os.makedirs(out_dir + '/predictions')
    os.makedirs(out_dir + '/bestweights')

    
# Define the path where you want to save the weights
checkpoint_path = out_dir + 'bestweights/' 

# Define the ModelCheckpoint callback
checkpoint = callbacks.ModelCheckpoint(
    filepath=checkpoint_path,
    save_weights_only=True,
    save_best_only=True,
    monitor='val_accuracy', 
    mode='max', 
    verbose=1
)

model.compile(
    optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=["accuracy"]
)
history = model.fit(train_dataset_1, validation_data=val_dataset_1,epochs=epochs,callbacks=[checkpoint])

# %%
# ---------------------- save results

# Load the saved, optimal  weights
model.load_weights(checkpoint_path)

# Compile the model with the same optimizer and loss function used during training
model.compile(optimizer=keras.optimizers.Adam(),
    loss='binary_crossentropy',
    metrics=["accuracy"])



# ----------- plot the training and validation loss
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.savefig(out_dir + '/plots/' + 'loss.png')

# ----------- plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='train accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.legend()
plt.savefig(out_dir + '/plots/' + 'accuracy.png')

# ----------- save weights
model.save(out_dir + '/weights/' + 'model.h5')

# ----------- save predictions
def visualize_predictions(index, test_dataset, out_dir):
    test_data_iter = iter(itertools.cycle(test_dataset))

    for i in range(index + 1):
        image_batch, label_batch = next(test_data_iter)

    wrapped_index = index % batches
    image = image_batch[wrapped_index].numpy()
    image = image[:,:,:3]
    image_rgb = np.stack(
        (
            (image[:,:,0] - np.min(image[:,:,0])) * 255.0 / (np.max(image[:,:,0]) - np.min(image[:,:,0])),
            (image[:,:,1] - np.min(image[:,:,1])) * 255.0 / (np.max(image[:,:,1]) - np.min(image[:,:,1])),
            (image[:,:,2] - np.min(image[:,:,2])) * 255.0 / (np.max(image[:,:,2]) - np.min(image[:,:,2]))
        ),
        axis=-1
    ).astype(np.uint8)
    prediction = model.predict(np.expand_dims(image, axis=0))[0]
    ground_truth = label_batch[wrapped_index].numpy()

    fig, ax = plt.subplots(2, 2, figsize=(10, 10))
    ax[0,0].imshow(image_rgb)
    ax[0,0].set_title("Input Image")
    ax[0,1].imshow(np.squeeze(ground_truth), cmap='gray')
    ax[0,1].set_title("Ground Truth")
    ax[1,0].imshow(np.squeeze(prediction), cmap='gray')
    ax[1,0].set_title("Prediction")
    ax[1,1].imshow(np.squeeze(prediction) > 0.5, cmap='gray')
    ax[1,1].set_title("Prediction (binary)")

    for i in range(2):
        for j in range(2):
            ax[i,j].axis('off')

    plt.savefig(out_dir + '/predictions/' + 'comparison_' + str(index) + '.png')
    #plt.show()
for i in range(80):
    visualize_predictions(i, test_dataset, out_dir)

# ----------- save metrics

if augment:
    augmetation_settings = {
    "flip_left_right": 0,
    "flip_up_down": 0,
    "gaussian_blur": 0.2,
    "random_noise": 0.0,
    "random_brightness": 0.5,
    "random_contrast": 0.5}
else:
    augmetation_settings = None


model_info = _02_evaluate_model.evaluate_model("DeepLabV3+ with Xception backbone (3 bands)", test_dataset_1, model, (256, 256, 3), shuffled, batches, epochs, augmentation_settings, threshold=0.5)
df = pd.DataFrame(model_info)
df.to_csv(os.path.join(out_dir, 'metrics.csv'), index=False)
